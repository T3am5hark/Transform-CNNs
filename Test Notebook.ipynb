# %%
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt
import numpy as np

from imageutils import cv2imshow

# %%
image = cv2.imread("Screenshot.png")
print(image.shape)
print(image.__class__)
print(image[0,0,0])
# Out:
# (1034, 1164, 3)
# <class 'numpy.ndarray'>
# 190

# %%
cv2imshow(image)
